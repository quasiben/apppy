# %%
# %run example.py
# Out:
# 2012-12-31
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#         <script type="text/javascript">
# ...
